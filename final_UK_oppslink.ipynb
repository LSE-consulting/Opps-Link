# %% [markdown]
# # Set of those contracts from API that match filter

# %%
import json
with open('output_data.json', 'r') as f:
    data = json.load(f)


filtered_titles_set = {entry['item']['title'] for entry in data['noticeList']}

filtered_titles_set
# Out:
# {'A DPS for sustainable and ethically sourced goods and services, delivering social value in local communities',
#  'AISI Challenge Fund Grant',
#  'Business Support Services DPS',
#  'CA15822 - Askham Bryan College - Farm Management',
#  'COV - Monitoring and Evaluation of School Improvement Activity',
#  'CP2545-24 School Meal Vouchers',
#  'Cleaning contract Public Toilets - Lynton &amp; Lynmouth',
#  'Climate Change Pull Facility (CIPF) - Evaluation Partner',
#  'Climate Innovation Pull Facility - Facility Manager - Invitation to Submit Initial Tenders',
#  'Commissioned Rehabilitative Services  - Expression of Interest',
#  'Communication and Print DPS Framework',
#  'Communications Marketplace',
#  'Construction Professional Services DPS',
#  'Construction Works and Associated Services including P24 Healthcare and Offsite Solutions',
#  'Consultancy Services Dynamic Purchasing System (DPS)',
#  'Consultancy Support',
#  'DPS - Dynamic Supplier List: Asset Solutions',
#  'Defence Medical Services Research Steering Group',
#  'Delivery Partner 2 (DP2) - WH:SHF and WH:LG',
#  'Delivery of a train-the-trainers course as part of the BNSSG Sponsorship Recruitment Scheme',
#  'Dynamic Purchasing System  Digital Connectivity: Services to Understanding Mobile Coverage and Performance',
#  'Dynamic Purchasing System (DPS) Energy Efficiency (EE)',
#  'Dynamic Purchasing System (DPS) for Sustainable and Ethically sourced Works/Construction projects (including professional services) delivering decarbonisation, biodiversity, energy efficiency, estate management and social value in local communities',
#  'Dynamic Purchasing System (DPS) for the provision of goods and services to drive social impact and improvement',
#  'Dynamic Purchasing System for Water Hygiene Services',
#  'Dynamic Purchasing System for the Provision of Material Waste Reception Services in Lincolnshire',
#  'EHRC 2526-01 Welsh Language Services',
#  'Economic Growth and Investment for Business Dynamic Purchasing System 2020',
#  'Electronic Payments and Associated Services',
#  'Employment, Skills and Economic Development Dynamic Purchasing System',
#  'Environmental &amp; Conventional Health &amp; Safety Services',
#  'Facilities Management &amp; Workplace Services DPS',
#  'Fund Administration &amp; Disbursement Services DPS',
#  'GM BGH Technical Innovation &amp; Commercialisation Specialist Support',
#  'Housing Maintenance &amp; Repair',
#  'Insurance Renewal',
#  'Insurance Services 3 DPS',
#  'Leasing and Loans Finance DPS',
#  'Local Net Zero Accelerator Pilot - Finance Support Services DPS',
#  'London &amp; Quadrant Housing Trust Financial Advisory Service Dynamic Purchasing System (DPS)',
#  'London and Quadrant Valuations Dynamic Purchasing System (DPS)',
#  'London and Quadrant Valuations Dynamic Purchasing System (DPS) archive',
#  'Lorry Driver Facilities Survey Year Three',
#  'NNLC484D - Operations, Site Work and Facilities Management Dynamic Purchasing System',
#  'Net Zero Consultant Apr25',
#  'Open Banking (Data, Digital Payments &amp; Confirmation of Payee Services) DPS',
#  'P0834 -1  Mentoring and Positive Activity Services - DPS',
#  'P0915 - Reopening of the Request To Participate (RTP) in a Flexible Contracting Agreement (FCA) for the provision of Refugee Support and Integration Services - Lots 1-5',
#  'PAN2497 - Domestic Homicide Review Independent Chair and Author Services',
#  'PURCON830 Invest East',
#  'Payment Solutions 3',
#  'Records Information Management, Digital Solutions and Associated Services',
#  'Research Services DPS',
#  'Research and Insights DPS',
#  'South Cambridgeshire District Council - Future Markets Trader Programme',
#  'South Cambridgeshire District Council - Markets Growth Programme',
#  'Supply of Insurance Products',
#  'Taskforce on Access to Climate Finance - Mauritius',
#  'Term Extension of the National Highway&#039;s Social Enterprise Dynamic Purchasing System',
#  'The delivery of a series of webinars for Adult Social Care Providers about Sponsorship Recruitment',
#  'This procurement aims to appoint a single supplier to deliver high quality, impactful business support to ambitious SMEs in East Sussex.  The contract will run for 8 months from August 2025 to March 2026 with a possible extension of a further 12 months (subject to funding).\\n      \\n      The UK Shared Prosperity Fund (UKSPF) is the UK Government&#039;s replacement for European Structural Investment Fund (ESiF) that included both the European Social Fund (ESF) and the European Regional Development Fund (ERDF), and is managed by the Ministry of Housing, Communities and Local Government.\\n      \\n      The funding for this contract, provided through UKSPF, is contingent upon ESCC receiving the fun',
#  'Transport Technology',
#  'UK Space Agency: Technical Assurance and Research and Development Consultancy',
#  'UKSA National Space Operations Centre (NSpOC) Upcoming Requirements',
#  'WCC - Dynamic Purchasing System (DPS) for Consultants and Project Support Services',
#  'Waste Management and Recycling',
#  'YPO - 001051 Insurance Placement DPS For Housing sector',
#  'YPO - 1198 Insurance Placement DPS II'}

# %% [markdown]
# # Get set of jobs already on Opps link

# %%
import requests

def get_all_job_titles(api_key, base_url="https://opps-link.com/api/jobs"):
    """
    Retrieve ALL active job titles from the API by paginating through all results
    
    Args:
        api_key (str): Your API key
        base_url (str): Base API URL
        
    Returns:
        set: Set of ALL active job titles across all pages
    """
    job_titles = set()
    page = 1
    limit = 100  # Max per API docs
    total_jobs = 0
    
    print("Starting to collect all job titles...")
    
    while True:
        params = {
            'page': page,
            'limit': limit,
            'active': 1,
            'api_key': api_key
        }
        
        try:
            response = requests.get(base_url, params=params)
            response.raise_for_status()
            data = response.json()
            
            # Check if we got jobs
            current_jobs = data.get('jobs', [])
            if not current_jobs:
                break  # No more jobs
                
            # Add all titles from this page
            for job in current_jobs:
                job_titles.add(job['title'])
            
            total_jobs += len(current_jobs)
            
            # Progress reporting
            print(f"Processed page {page} - found {len(current_jobs)} jobs (total: {total_jobs})")
            
            # Check if we should continue
            if len(current_jobs) < limit:
                break  # Last page
                
            page += 1
            
        except requests.exceptions.RequestException as e:
            print(f"Error on page {page}: {e}")
            break
            
    print(f"\nFinished! Collected {len(job_titles)} unique titles from {total_jobs} jobs across {page} pages")
    return job_titles

# Usage
api_key = "37c597e7bb52d26099ede8b8aa43b270"
all_titles = get_all_job_titles(api_key)

all_titles=set(all_titles)
# Out:
# Starting to collect all job titles...
# Processed page 1 - found 100 jobs (total: 100)
# Processed page 2 - found 100 jobs (total: 200)
# Processed page 3 - found 87 jobs (total: 287)
#
# Finished! Collected 287 unique titles from 287 jobs across 3 pages

# %% [markdown]
# # Get all existing employers and employer ids

# %%
import requests

def get_all_employers(api_key, base_url="https://opps-link.com/api/employers"):
    """
    Retrieve ALL employers with their IDs from the API by paginating through all results
    
    Args:
        api_key (str): Your API key
        base_url (str): Base API URL
        
    Returns:
        dict: Dictionary mapping employer names (lowercase) to IDs
        list: List of all employer dictionaries
    """
    employers_dict = {}  # This will now be {name_lowercase: id}
    employers_list = []
    page = 1
    limit = 100  # Adjust based on API's max limit
    total_processed = 0
    
    print("Starting to collect all employers...")
    
    while True:
        params = {
            'page': page,
            'limit': limit,
            'api_key': api_key
        }
        
        try:
            response = requests.get(base_url, params=params)
            response.raise_for_status()
            data = response.json()
            
            # Check if we got employers
            current_employers = data.get('employers', [])
            if not current_employers:
                break  # No more employers
                
            # Process employers from this page
            for employer in current_employers:
                employer_id = employer['id']
                employer_name = employer['company_name']
                # Use lowercase name for case-insensitive matching
                employers_dict[employer_name.lower()] = employer_id
                employers_list.append(employer)
            
            total_processed += len(current_employers)
            
            # Progress reporting
            print(f"Processed page {page} - found {len(current_employers)} employers (total: {total_processed})")
            
            # Check if we should continue
            if len(current_employers) < limit:
                break  # Last page
                
            page += 1
            
        except requests.exceptions.RequestException as e:
            print(f"Error on page {page}: {e}")
            break
            
    print(f"\nFinished! Collected {len(employers_dict)} unique employers across {page} pages")
    return employers_dict, employers_list

# Usage
api_key = "37c597e7bb52d26099ede8b8aa43b270"
employers_dict, employers_list = get_all_employers(api_key)

# Now employers_dict is {name_lowercase: id} which is what you need
print(f"Sample employer: {list(employers_dict.items())[0]}")
# Out:
# Starting to collect all employers...
# Processed page 1 - found 100 employers (total: 100)
# Processed page 2 - found 100 employers (total: 200)
# Processed page 3 - found 100 employers (total: 300)
# Processed page 4 - found 100 employers (total: 400)
# Processed page 5 - found 92 employers (total: 492)
#
# Finished! Collected 485 unique employers across 5 pages
# Sample employer: ('british council', 9)

# %%
employers_dict
# Out:
# {'british council': 9,
#  'defra - department for environment, food and rural affairs': 10,
#  'european parliament - dg for communication (comm)': 14,
#  'european committee of the regions': 15,
#  'european commission - eurostat': 16,
#  'european union aviation safety agency (easa)': 18,
#  'european food safety authority (efsa)': 19,
#  'united nations development program, panama (undp)': 20,
#  'northern ireland housing executive': 21,
#  'cpd - supplies and services division': 22,
#  'european centre for disease prevention and control (ecdc)': 23,
#  'european commission - dg for neighbourhood and enlargement negotiations (dg near)': 33,
#  'european commission - european climate, infrastructure and environment executive agency (cinea)': 34,
#  'european commission - dg for defence industry and space (defis)': 35,
#  'european investment bank (eib)': 37,
#  'european commission - dg for education, youth, sport and culture (eac)': 38,
#  'european commission - service for foreign policy instruments (fpi)': 39,
#  'european commission - dg for trade (trade)': 40,
#  'european foundation for the improvement of living and working conditions (eurofound)': 41,
#  'european parliament - dg for personnel': 43,
#  'european commission - dg for communications networks, content and technology (connect)': 44,
#  'european foundation for the improvement of living and working conditions  (eurofound)': 46,
#  'european commission - dg employment, social affairs and inclusion (empl)': 47,
#  'european commission - dg research and innovation (rtd)': 48,
#  'european commission - dg regional and urban policy (regio)': 49,
#  'european commission - dg for climate action (clima)': 50,
#  'european commission - dg for international partnerships (intpa)': 51,
#  'wwf-uk (world wide fund for nature)': 53,
#  'the climate change committee (ccc)': 54,
#  'doncaster council': 55,
#  'warwickshire county council': 56,
#  'science museum group': 57,
#  'uk research and innovation - biotechnology and biological sciences research council': 80,
#  'european commission - joint research centre - seville (jrc-svq)': 82,
#  'european agency for the operational management of large-scale it systems in the area of freedom, security and justice (eu-lisa)': 83,
#  'ofcom': 84,
#  'money and pensions service': 85,
#  'european commission - dg for mobility and transport (move)': 90,
#  'uk shared business services': 92,
#  'european commission - dg for energy (ener)': 95,
#  'solicitors regulation authority': 102,
#  'power to change': 239,
#  'international labour organization': 106,
#  'international fund for agricultural development (ifad)': 107,
#  'un women': 108,
#  'world health organization': 109,
#  'uk research & innovation (ukri)': 110,
#  'british film institute': 117,
#  'safefood': 119,
#  'liverpool city region combined authority': 120,
#  'nhs race and health observatory': 121,
#  'agriculture and horticulture development board (ahdb)': 125,
#  'oxford brookes university': 126,
#  'sunderland city council': 127,
#  'advance he': 128,
#  "the children's society": 129,
#  'salisbury nhs foundation trust': 130,
#  'office for students': 131,
#  'welsh government': 132,
#  'arbeids- og inkludering departementet (norwegian ministry of labour and social inclusion)': 133,
#  'malaria consortium': 139,
#  'oxfordshire county council': 140,
#  'european commission - dg for health and food safety (sante)': 141,
#  'education workforce council (wales)': 142,
#  'rethink ireland': 143,
#  "the mayor's office for policing and crime (mopac)": 144,
#  'foodcloud': 145,
#  'department for business, energy & industrial strategy': 146,
#  'ministry of foreign affairs (netherlands)': 147,
#  'deutsche gesellschaft für internationale zusammenarbeit (giz)': 148,
#  'department of children, equality, disability, integration and youth (ireland)': 149,
#  'the scottish government': 150,
#  'office for product safety and standards (opss)': 151,
#  'european commission - secretariat-general': 153,
#  'european commission - financial stability, financial services and capital markets union (fisma)': 154,
#  'north northamptonshire council': 170,
#  'foreign commonwealth and development office (fcdo)': 171,
#  'department for international trade (dit)': 172,
#  'council of europe': 173,
#  'wellcome trust': 198,
#  'food standards scotland': 200,
#  'bord bia - irish food board': 201,
#  'federbio': 202,
#  'hayel saeed anam group (hsa)': 203,
#  'european commission - dg for competition policy (comp)': 204,
#  'climatexchange (cxc)': 205,
#  'waterways ireland': 218,
#  'devon county council': 219,
#  'national institute for health and care research': 222,
#  'waste & resources action programme': 225,
#  'university college dublin': 226,
#  'department of the environment, climate and communications (ireland)': 227,
#  'carmarthenshire county council': 228,
#  'the north east ambulance service foundation trust (neas)': 229,
#  'european commission - dg for environment': 230,
#  'british red cross': 231,
#  'department of enterprise, trade and employment (ireland)': 232,
#  "queen's university belfast": 233,
#  'european commission, dg for environment (env)': 237,
#  'mental health reform': 238,
#  'hmrc': 240,
#  'equality and human rights commission': 241,
#  'comic relief': 242,
#  'the royal borough of kingston upon thames': 243,
#  'mayors office for policing and crime': 244,
#  'the national council for curriculum and assessment (ncca)': 245,
#  'bolsover district council': 246,
#  'falmouth town council': 247,
#  'local government association': 630,
#  'world bank group': 249,
#  'devon and somerset fire and rescue authority': 250,
#  'cefas': 251,
#  'european council - council of the european union': 253,
#  'office for environmental protection': 254,
#  'financial reporting council': 255,
#  'welthungerhilfe': 256,
#  'chemonics': 257,
#  'university of edinburgh': 258,
#  'birmingham city council': 260,
#  'braintree district council': 261,
#  'kent county council': 262,
#  'glen dimplex heating and ventilation (gdhv)': 263,
#  'westminster foundation for democracy': 502,
#  'office for standards in education (ofsted)': 265,
#  'center for aging better': 266,
#  '': 267,
#  'west yorkshire combined authority (wyca)': 275,
#  'central bank of ireland': 276,
#  'food standards agency (fsa)': 277,
#  'orkney islands council': 278,
#  'tourism ireland': 279,
#  'office of the police and crime commissioner for leicestershire (opccl)': 280,
#  'tees valley combined authority group, and teesside international (tvcati)': 281,
#  'cwmpas': 282,
#  'cumbria county council (ccc)': 283,
#  'tewkesbury borough council': 285,
#  'south downs national park authority (sdnpa)': 286,
#  'department for digital, culture, media & sport (dcms)': 288,
#  'norfolk county council (ncc)': 289,
#  'norway ministry of foreign affairs': 291,
#  'trade mark east africa': 292,
#  'innovate uk': 294,
#  'european innovation council': 295,
#  'european research council': 296,
#  'arts and humanities research council (ahrc)': 297,
#  'national nuclear laboratory': 299,
#  'north of tyne combined authority (ntca)': 301,
#  'asian development bank (adb)': 302,
#  'education, audiovisual and culture executive agency (eacea)': 303,
#  'east suffolk council': 304,
#  'nottingham city council': 305,
#  'knowledge transfer network limited': 306,
#  'qualifications wales': 307,
#  'office for national statistics': 308,
#  'kirklees council': 309,
#  'leeds city council': 310,
#  'london borough of redbridge': 311,
#  'aberystwyth university': 312,
#  'met office': 313,
#  'commonwealth secretariat': 315,
#  'save the children': 316,
#  'south dublin county partnership': 317,
#  'milton keynes council': 318,
#  'walsall council': 322,
#  'future generations commissioner for wales': 324,
#  'the executive office': 325,
#  'ballyfermot chapelizod partnership (bcp)': 326,
#  'london borough of waltham forest': 327,
#  'education and training foundation': 328,
#  'maidstone borough council': 329,
#  'cork city council': 330,
#  'competition and markets authority': 331,
#  'nhs england': 334,
#  'dudley metropolitan borough council': 335,
#  'monmouthshire county council': 336,
#  'offshore renewable energy catapult': 337,
#  'centrepoint': 340,
#  'transport for london': 343,
#  'general medical council': 344,
#  'food & drink wales sustainable scale up cluster': 346,
#  'department of foreign affairs (ireland)': 347,
#  'traveller counselling service': 348,
#  'london borough of sutton': 349,
#  'european investment fund': 350,
#  'the british academy': 352,
#  'scottish land commission': 353,
#  'belfast city council': 354,
#  'quality and qualifications ireland (qqi)': 355,
#  'the housing agency': 358,
#  'office of rail and road': 359,
#  'london borough of barking and dagenham': 360,
#  'london borough of lambeth': 361,
#  'shine': 362,
#  'chwarae teg': 363,
#  'social work england': 365,
#  'department for transport': 366,
#  'natural england': 367,
#  'commission for communications regulation': 621,
#  'historic england': 369,
#  'european commission - dg for agriculture and rural development (dg agri)': 370,
#  'invest norther ireland': 372,
#  'tu dublin': 373,
#  'the health and safety executive (hse)': 376,
#  'macmillan cancer support': 377,
#  'historic environment scotland': 378,
#  'the health foundation': 379,
#  'the national lottery community fund': 381,
#  'social care wales': 382,
#  'hcc / meat promotion wales': 383,
#  'food and agriculture organization': 384,
#  'centre for ageing better': 385,
#  'safer london': 386,
#  'the teaching council': 387,
#  'department for education': 391,
#  'department of health and social care': 392,
#  'west mercia police procurement department': 393,
#  'clare children and young people’s services committee': 395,
#  'university of leeds': 396,
#  'groundswell': 397,
#  'mental health commission': 398,
#  'arts council england': 399,
#  'nesta': 400,
#  'hartlepool borough council': 402,
#  'health service executive': 403,
#  'the trussell trust': 404,
#  'department of housing, local government and heritage': 405,
#  'youth endowment fund': 406,
#  'european free trade association (efta)': 407,
#  'aspect': 410,
#  "women's aid": 411,
#  'imperial war museums': 555,
#  'the uk evaluation society': 419,
#  'focus ireland': 420,
#  'london borough of southwark': 423,
#  'nhs shared business services': 424,
#  'department for levelling up, housing and communities': 425,
#  'crisis': 427,
#  'apec secretariat': 428,
#  'integrated education fund (ief)': 429,
#  "the women's organisation": 430,
#  'hse national social inclusion office': 431,
#  'bishop wilkinson catholic education trust (bwcet)': 432,
#  'education procurement service (eps)': 433,
#  'marie curie': 437,
#  'cambridgeshire county council': 438,
#  'st giles trust': 439,
#  'national heritage memorial fund': 556,
#  'tilbury on the thames trust': 441,
#  'general optical council': 442,
#  'united nations economic commission for africa (uneca)': 443,
#  'cheshire & warrington local enterprise partnership': 444,
#  'gamble aware': 445,
#  'avon & somerset police and crime commissioner (pcc)': 446,
#  'jameel observatory': 448,
#  'essex county council': 449,
#  "the mayor of london's violence reduction unit": 450,
#  'uwe bristol': 451,
#  'crown prosecution service': 452,
#  'european parliament, directorate-general for internal policies of the union': 453,
#  'nottingham city care partnership cic': 454,
#  'leicestershire county council': 456,
#  'european commission, directorate-general for migration and home affairs': 457,
#  'daughters of charity child and family service': 458,
#  'breast cancer now': 459,
#  'bude climate partnership': 460,
#  'social mobility commission': 461,
#  'cordaid': 462,
#  'department of health (ireland)': 463,
#  "jessie may trust children's hospice at home": 466,
#  'the growth company': 467,
#  'hand in hand india': 468,
#  'european commission directorate-general justice and consumers': 469,
#  'nurture uk': 472,
#  'royal botanic garden edinburgh': 473,
#  'ministry for environment energy and enterprise (malta)': 474,
#  'joint nature conservation committee': 475,
#  'african union development agency (auda-nepad)': 477,
#  'east sussex city council': 478,
#  'greater manchester combined authority': 626,
#  'sport england': 480,
#  'hackney council': 481,
#  'environmental standards scotland (ess)': 482,
#  'european institute for gender equality (eige)': 483,
#  'parliament of uganda': 484,
#  'european union agency for fundamental rights (fra)': 488,
#  'leicester city council': 489,
#  'world food programme': 490,
#  'the armed forces covenant fund': 491,
#  'the baring foundation': 492,
#  'department for science, innovation and technology': 494,
#  'zero waste scotland': 495,
#  'european labour authority': 496,
#  'university of winchester': 497,
#  'the liminal space': 499,
#  'natural history museum': 500,
#  'stroud district council': 501,
#  'humanity and inclusion': 503,
#  'watford borough council': 504,
#  'salford city council': 505,
#  'caritas': 506,
#  'department for energy security & net zero': 510,
#  'impact on urban health': 511,
#  'the euromed feminist initiative': 512,
#  'the office of the police & crime commissioner': 514,
#  'ukhsa': 515,
#  'surrey county council': 516,
#  "national children's bureau": 517,
#  'natctso': 518,
#  'merseyside police - procurement department police headquarters': 519,
#  "united nations children's fund (unicef)": 520,
#  'visitengland': 521,
#  'torbay and south devon nhs foundation trust': 524,
#  'alzheimer scotland': 525,
#  'undp india': 526,
#  'horizon europe': 530,
#  'department for business and trade': 531,
#  'the national trust for places of historic interest or natural beauty': 532,
#  'midlands & lancashire c s u': 533,
#  'cambridge city council': 534,
#  'irise international': 535,
#  'uk health security agency': 536,
#  'national space academy': 537,
#  'worldskills uk': 538,
#  'environmental protection agency ireland': 542,
#  'equality commission for northern ireland': 543,
#  'generation': 544,
#  'carmarthenshire county council county': 545,
#  'uk home office': 546,
#  'winchester city council': 549,
#  'alcohol forum ireland': 554,
#  'local trust': 557,
#  'european commission - dg just - justice and consumers': 558,
#  'the carbon trust': 559,
#  'sandwell metropolitan council': 560,
#  'irish tenant engagement network research': 561,
#  'ministry of finance ghana': 562,
#  'depaul ireland': 563,
#  'the heritage council': 566,
#  'the national library of wales': 572,
#  'the acc group': 574,
#  'derry city and strabane district council': 575,
#  'apex housing association': 576,
#  'financial services compensation scheme': 577,
#  'the norwegian ministry of finance / finansdepartementet oslo': 578,
#  'university of exeter': 579,
#  'nhs arden and greater east midlands commissioning support unit': 580,
#  'inspiring scotland': 582,
#  'consumer council for water': 583,
#  'the cabinet office': 584,
#  'national autistic society': 585,
#  'department for transport (dft)': 586,
#  'constellia public': 587,
#  'connected places catapult': 588,
#  'west midlands combined authority': 589,
#  'danish refugee council': 590,
#  'international planned parenthood federation': 592,
#  'secretariat of the union for the mediterranean (ufm secretariat)': 594,
#  'save the children nigeria': 595,
#  'department of foreign affairs and trade (australian government)': 596,
#  'portsmouth city council': 597,
#  'african development bank': 598,
#  'test employer xyz': 623,
#  'derbyshire county council': 624,
#  'desnz': 625,
#  'south liverpool homes': 627,
#  'chemonics international, inc.': 628,
#  'douglas city council': 629,
#  'leighton linslade town council': 631,
#  'west midlands police authority': 632,
#  'north york moors national park authority': 633,
#  'serco limited': 634,
#  'nottinghamshire county council': 635,
#  'uk space agency': 636,
#  'waste &amp; resources action programme': 637,
#  'university of bristol': 638,
#  'home office': 639,
#  'walsall council e-tendering': 640,
#  'business energy and industrial strategy': 641,
#  'crown commercial service': 642,
#  'dsit': 643,
#  'care &amp; support west limited': 653,
#  'south cambridgeshire district council': 654,
#  'askham bryan college': 655,
#  'transport focus': 656,
#  'wind energy ireland': 657,
#  'statsbygg': 658,
#  'ntnu': 659,
#  'universität zürich assetmanagement': 660,
#  'european food safety authority': 661,
#  'molde kommune': 662,
#  'fingal county council_371': 663,
#  'direktoratet for forvaltning og økonomistyring (dfø)': 664,
#  'oslo kommune v/ klimaetaten': 665,
#  'universitetet i oslo': 666,
#  'department of transport': 667,
#  'kunnskapsdepartementet': 668,
#  'deutsche gesellschaft für internationale zusammenarbeit (giz) gmbh': 669,
#  'department of defence': 670,
#  'anci toscana': 671,
#  'espon egtc (european group for territorial cohesion)': 672,
#  'forsvarsdepartementet': 673,
#  'fáilte ireland-national tourism development authority': 674,
#  'justis- og beredskapsdepartementet': 675,
#  'government of montenegro, ministry of public works': 676,
#  'the land development agency': 677,
#  'european central bank': 678,
#  'helse- og omsorgsdepartementet': 679,
#  'ministry of environment, urbanization and climate change/ general directorate of european union and foreign relations/ department of european union investments': 680,
#  'european commission, dg clima - climate action': 681,
#  'nærings- og fiskeridepartementet': 682,
#  'universitetet i agder': 683,
#  'university college dublin ( ucd )': 684,
#  'health service executive (hse)': 685,
#  'european commission, intpa - international partnerships': 686,
#  'newkd': 687,
#  'finnish national agency for education': 688,
#  'european union drugs agency': 689,
#  'utenriksdepartementet': 690,
#  'instech hub ireland clg (t/a instech.ie)': 691,
#  'european climate, infrastructure and environment executive agency (cinea), cinea - european climate, infrastructure and environment executive agency': 692,
#  'european commission, enest - enlargement and eastern neighbourhood': 693,
#  'digital skills accelerator africa e.v.': 694,
#  "agenzia per l'italia digitale": 695,
#  'department of fisheries and marine research': 696,
#  'waterways ireland_225': 697,
#  'commission for regulation of utilities': 698,
#  'nasjonal kommunikasjonsmyndighet (nkom)': 699,
#  'european commission, dg move - mobility and transport': 700,
#  'marine institute_1141': 701,
#  'sectoral procurement directorate': 702,
#  'teagasc - the agriculture and food development authority': 703,
#  'health and digital executive agency (hadea) , hadea - health and digital executive agency': 704,
#  'kommunal- og distriktsdepartementet': 705,
#  'jernbanedirektoratet': 706,
#  'national transport authority_1149': 707,
#  'ministry of foreign affairs of denmark': 708,
#  'coillte cga': 709,
#  'norsk tipping as': 710,
#  'food safety authority of ireland': 711,
#  'uit norges arktiske universitet': 712,
#  'miljødirektoratet': 713,
#  'arbeids- og velferdsetaten': 714,
#  'european commission, dg trade - trade': 715,
#  'larvik kommune': 716,
#  'peter mcverry trust_121127': 717,
#  'norce': 718,
#  'fraunhofer-gesellschaft - einkauf b12': 719,
#  'european commission, dg jrc - joint research centre': 720,
#  'department of tourism culture arts gaeltacht sport media': 721,
#  'norges forskningsråd': 722,
#  'arbeids- og inkluderingsdepartementet': 723,
#  'european commission, dg defis - defence industry and space': 724,
#  'politiets fellestjenester': 725,
#  'norsk helsenett sf': 726,
#  'iarnród eireann-irish rail': 727,
#  'regeringskansliet': 728,
#  'ministry of foreign affairs': 729,
#  'department of health_1121': 730,
#  'transport infrastructure ireland (tii)': 731,
#  'westmeath county council': 732,
#  'european foundation for the improvement of living and working conditions': 733,
#  'department of housing local government and heritage': 734,
#  'european commission, dg fisma - financial stability, financial services and capital markets union': 735,
#  'galway county council': 736,
#  'department of enterprise trade and employment': 737,
#  'technological university dublin (tu dublin)': 738,
#  'artsdatabanken': 739,
#  'the irish air navigation service': 740,
#  'climate-kic holding b.v.': 741,
#  'kultur- og likestillingsdepartementet': 742,
#  '3 counties energy agency': 743,
#  'nordre follo kommune': 744,
#  'kulturdirektoratet': 745,
#  'sida': 746,
#  'the health research board': 747,
#  'department of contracts': 748,
#  'norad – direktoratet for utviklingssamarbeid': 749,
#  'ministerie van economische zaken, rijksdienst voor ondernemend nederland (rvo)': 750,
#  'statsforvalterens fellestjenester': 751,
#  'midt-telemark kommune': 752,
#  'southern regional assembly': 753,
#  'medietilsynet': 754,
#  'naturvårdsverket': 755,
#  'federal department of economic affairs, education and research eaer': 756,
#  'the research council of norway': 757}

# %% [markdown]
# # Attempt 1

# %%
import requests
from datetime import datetime, timezone
from parsel import Selector
import json
import html
import re
from dateutil import parser

# Configuration
JOB_API_URL = "https://opps-link.com/api/jobs"
EMPLOYER_API_URL = "https://opps-link.com/api/employers"
API_KEY = "37c597e7bb52d26099ede8b8aa43b270"
HEADERS = {"Content-Type": "application/json"}

# Load existing data
with open('output_data.json', 'r') as f:
    json_data = json.load(f)

# Initialize sets/dicts from your existing data
filtered_titles_set = {entry['item']['title'] for entry in json_data['noticeList']}
contract_titles = set()  # Should be populated with existing job titles from your site
employer_dict = {}       # Should be populated with existing employers {name: id}

def clean_description(description):
    """Clean and format the description text."""
    if not description:
        return "Not Disclosed"
    cleaned = html.unescape(description)
    cleaned = cleaned.replace('\r\n', ' ').replace('\n', ' ')
    return ' '.join(cleaned.split()).strip()

def create_employer(company_name):
    """Create a new employer and return their ID"""
    # Generate a standardized email and password
    clean_name = re.sub(r'[^a-z0-9_]', '', company_name.lower().replace(' ', '_'))
    email = f"{clean_name}@opps-link.com"
    password = f"{clean_name}_123!"  # Simple password that meets requirements
    
    payload = {
        "api_key": API_KEY,
        "email": email,
        "password": password,  # Added required password field
        "company_name": company_name,
        "company_description": f"<p>{company_name}</p>",
        "active": 1,
        "featured": 0,
        "registration_date": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "full_name": company_name,  # Some APIs require this
        "location": "United Kingdom",  # Default location
        "website": ""  # Empty but required field
    }
    
    try:
        response = requests.post(EMPLOYER_API_URL, json=payload, headers=HEADERS)
        if response.status_code == 201:
            employer_id = response.json().get('id')
            print(f"✅ Created new employer: {company_name} (ID: {employer_id})")
            return employer_id
        else:
            print(f"❌ Failed to create employer {company_name}: {response.text}")
            return None
    except Exception as e:
        print(f"🔥 Error creating employer: {str(e)}")
        return None

def create_job(job_data):
    """Create a new job posting"""
    try:
        response = requests.post(JOB_API_URL, json=job_data, headers=HEADERS)
        if response.status_code == 201:
            job_id = response.json().get('id')
            print(f"✅ Successfully posted job: {job_data['title']} (ID: {job_id})")
            return True
        else:
            print(f"❌ Failed to post job {job_data['title']}: {response.text}")
            return False
    except Exception as e:
        print(f"🔥 Error posting job: {str(e)}")
        return False

def process_contracts():
    base_url = "https://www.contractsfinder.service.gov.uk/Search/Results?page="
    
    for page_number in range(1, 5):
        url = base_url + str(page_number)
        try:
            response = requests.get(url)
            response.raise_for_status()
            sel = Selector(text=response.text)
            contract_nodes = sel.xpath('//div[@class="search-result"]')
            
            if not contract_nodes:
                break
                
            for node in contract_nodes:
                name = node.xpath('.//div[@class="search-result-header"]/@title').get()
                
                if not name or name not in filtered_titles_set or name in all_titles:
                    continue
                
                additional_fields = title_to_details.get(name, {})
                client_name = additional_fields.get('client', 'Not Disclosed')
                client_key = client_name.lower()
                
                print(f"Processing job: {name} | Employer: {client_name}")
                
                employer_id = employers_dict.get(client_key)
                
                if employer_id is None:
                    print(f"Employer '{client_name}' not found, attempting to create...")
                    employer_id = create_employer(client_name)
                    if employer_id:
                        employers_dict[client_key] = employer_id
                    else:
                        continue
                else:
                    print(f"Found existing employer: {client_name} (ID: {employer_id})")
                
                contract_value = node.xpath('.//strong[contains(text(), "Contract value")]/following-sibling::text()').get()
                contract_link = node.xpath('.//div[@class="search-result-header"]//a/@href').get()
                
                # Handle deadline date - use same value for both expiration_date and application deadline
                deadline_date = additional_fields.get('deadline_date')
                if deadline_date:
                    try:
                        # Parse the date string to ensure it's valid
                        parsed_date = parser.parse(deadline_date)
                        # Format as YYYY-MM-DD for API compatibility
                        formatted_date = parsed_date.strftime("%Y-%m-%d")
                    except:
                        formatted_date = '2025-12-31'  # Default fallback
                else:
                    formatted_date = '2025-12-31'  # Default fallback
                
                job_data = {
                    "api_key": API_KEY,
                    "active": 1,
                    "featured": 0,
                    "title": name,
                    "employer_id": employer_id,
                    "description": additional_fields.get('description', ''),
                    "how_to_apply": "contact@example.com",
                    "activation_date": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
                    "expiration_date": formatted_date,  # Uses deadlineDate
                    "location": additional_fields.get('region', 'Not Specified'),
                    "custom_fields": [
                        {"name": "Contract Value", "value": contract_value.strip() if contract_value else 'Not Disclosed'},
                        {"name": "Contract Link", "value": contract_link.strip() if contract_link else ''},
                        {
                            "name": "Application deadline", 
                            "value": formatted_date,  # Same as expiration_date
                            "type": "date"
                        }
                    ]
                }
                
                if create_job(job_data):
                    contract_titles.add(name)
                    
        except Exception as e:
            print(f"Error processing page {page_number}: {str(e)}")
            continue


# Create title_to_details mapping
title_to_details = {}
for entry in json_data['noticeList']:
    item = entry['item']
    title = item['title']
    title_to_details[title] = {
        'client': item.get('organisationName', 'Not Disclosed'),
        'description': clean_description(item.get('description')),
        'deadline_date': item.get('deadlineDate', '2025-12-31 23:59:59'),
        'region': item.get('regionText', item.get('region', 'Not Disclosed')),
        'cpv_codes': item.get('cpvCodes', 'Not Available'),
        'notice_status': item.get('noticeStatus', 'Unknown')
    }

# Start processing
process_contracts()
print("Job processing complete!")
# Out:
# Job processing complete!

# %% [markdown]
# # EU contracts attempt 1

# %%
def create_job(job_data):
    """Create a new job posting."""
    try:
        response = requests.post("https://opps-link.com/api/jobs", json=job_data, headers=HEADERS)
        if response.status_code == 201:
            job_id = response.json().get('id')
            print(f"✅ Successfully posted job: {job_data['title']} (ID: {job_id})")
            return True
        else:
            print(f"❌ Failed to post job {job_data['title']}: {response.status_code} - {response.text}")
            return False
    except Exception as e:
        print(f"🔥 Error posting job {job_data['title']}: {str(e)}")
        return False
    
def create_employer(company_name):
    """Create a new employer and return their ID."""
    clean_name = re.sub(r'[^a-z0-9_]', '', company_name.lower().replace(' ', '_'))
    email = f"{clean_name}@opps-link.com"
    password = f"{clean_name}_123!"

    payload = {
        "api_key": API_KEY_OPPSLINK,
        "email": email,
        "password": password,
        "company_name": company_name,
        "company_description": f"<p>{company_name}</p>",
        "active": 1,
        "featured": 0,
        "registration_date": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "full_name": company_name,
        "location": "EU",
        "website": ""
    }

    try:
        response = requests.post("https://opps-link.com/api/employers", json=payload, headers=HEADERS)
        if response.status_code == 201:
            employer_id = response.json().get('id')
            print(f"✅ Created employer: {company_name} (ID: {employer_id})")
            return employer_id
        else:
            print(f"❌ Failed to create employer {company_name}: {response.status_code} - {response.text}")
            return None
    except Exception as e:
        print(f"🔥 Error creating employer {company_name}: {str(e)}")
        return None

# %%
import httpx
import json
import time
from datetime import datetime, timezone
import html
import re
import requests

# Constants
API_KEY_OPPSLINK = "37c597e7bb52d26099ede8b8aa43b270"
HEADERS = {"Content-Type": "application/json"}
EU_API_KEY = "844692394d814535a9ed3a37f0ab01e1"
EU_API_URL = "https://tedweb.api.ted.europa.eu/private-search/api/v1/notices/search"

# Step 1: Get all employers and job titles from OppsLink
employers_dict, employers_list = get_all_employers(API_KEY_OPPSLINK)
all_titles = get_all_job_titles(API_KEY_OPPSLINK)

def clean_description(description):
    """Clean and format the description text."""
    if not description:
        return "Not Disclosed"
    cleaned = html.unescape(description)
    cleaned = cleaned.replace('\r\n', ' ').replace('\n', ' ')
    return ' '.join(cleaned.split()).strip()

def fetch_data(payload, page):
    for attempt in range(5):
        response = httpx.post(EU_API_URL, headers={
            "Content-Type": "application/json",
            "Authorization": f"Bearer {EU_API_KEY}",
        }, json=payload)

        if response.status_code == 200:
            return response.json().get("notices", [])
        elif response.status_code == 429:
            time.sleep(2 ** attempt)
        else:
            break
    return []

# Step 2: Scrape and filter EU contracts
all_eu_contracts = []
for page in range(1, 11):
    payload = {
        "query": "(classification-cpv IN (66171000 73100000 73200000 73300000 75211200 79411000 90713000)) AND (notice-type IN (qu-sy pin-cfc-standard subco cn-desg cn-social cn-standard pin-cfc-social))  SORT BY publication-number DESC",
        "page": page,
        "limit": 50,
        "fields": [
            "classification-cpv", "BT-24-Procedure", "BT-27-Procedure", "BT-27-Part", "BT-27-Lot",
            "publication-number", "BT-5141-Procedure", "BT-5141-Part", "BT-5141-Lot",
            "BT-5071-Procedure", "BT-5071-Part", "BT-5071-Lot", "BT-727-Procedure",
            "BT-727-Part", "BT-727-Lot", "place-of-performance", "procedure-type",
            "contract-nature", "buyer-name", "buyer-country", "publication-date",
            "deadline-receipt-request", "notice-title", "official-language", "notice-type",
            "links"
        ],
        "validation": False,
        "scope": "ACTIVE",
        "language": "EN"
    }

    new_contracts = fetch_data(payload, page)

    for contract in new_contracts:
        title = contract.get("notice-title", {}).get("eng", "")
        if not title or title in all_titles:
            continue

        official_languages = ', '.join([lang['label'] for lang in contract.get("official-language", [])])
        if 'English' not in official_languages:
            continue

        deadline = contract.get("deadline-receipt-request", [])
        deadline_date = deadline[0] if deadline else "2050-01-01T00:00:00Z"

        country = ', '.join({place['label'] for place in contract.get("place-of-performance", [])})
        client_name = contract.get("buyer-name", {}).get("eng", [""])[0] or "Not Disclosed"
        description = clean_description(contract.get("BT-24-Procedure", {}).get("eng", ""))
        cpv_codes = ', '.join([c["value"] for c in contract.get("classification-cpv", [])])
        value = contract.get("BT-27-Procedure", "") or "Unavailable"
        link = contract.get("links", {}).get("html", {}).get("ENG", "")

        all_eu_contracts.append({
            "title": title,
            "deadline": deadline_date,
            "country": country,
            "client": client_name,
            "description": description[:2000],
            "cpv_codes": cpv_codes,
            "value": value,
            "link": link
        })

    time.sleep(5)

print(f"✅ {len(all_eu_contracts)} contracts ready for processing")

# Step 3: Upload to OppsLink
for contract in all_eu_contracts:
    title = contract['title']
    if title in all_titles:
        continue

    client_name = contract['client']
    client_key = client_name.lower()

    employer_id = employers_dict.get(client_key)
    if employer_id is None:
        print(f"🔍 Employer '{client_name}' not found. Attempting to create...")
        employer_id = create_employer(client_name)
        if employer_id:
            employers_dict[client_key] = employer_id
        else:
            print(f"🚫 Skipping contract '{title}' — failed to create employer.")
            continue


    # Format deadline
    try:
        formatted_deadline = datetime.fromisoformat(contract["deadline"]).strftime("%Y-%m-%d")
    except:
        formatted_deadline = "2025-12-31"

    job_data = {
        "api_key": API_KEY_OPPSLINK,
        "active": 1,
        "featured": 0,
        "title": contract['title'],
        "employer_id": employer_id,
        "description": contract['description'],
        "how_to_apply": "contact@example.com",
        "activation_date": datetime.now(timezone.utc).strftime("%Y-%m-%d %H:%M:%S"),
        "expiration_date": formatted_deadline,
        "location": contract['country'] or "EU",
        "custom_fields": [
            {"name": "Contract Value", "value": contract['value']},
            {"name": "Contract Link", "value": contract['link']},
            {"name": "CPV Codes", "value": contract['cpv_codes']},
            {"name": "Application deadline", "value": formatted_deadline, "type": "date"}
        ]
    }

    success = create_job(job_data)
    if success:
        all_titles.add(contract['title'])

print("✅ EU contracts uploaded to OppsLink")
# Out:
# Starting to collect all employers...
# Processed page 1 - found 100 employers (total: 100)
# Processed page 2 - found 100 employers (total: 200)
# Processed page 3 - found 100 employers (total: 300)
# Processed page 4 - found 100 employers (total: 400)
# Processed page 5 - found 92 employers (total: 492)
#
# Finished! Collected 485 unique employers across 5 pages
# Starting to collect all job titles...
# Processed page 1 - found 100 jobs (total: 100)
# Processed page 2 - found 100 jobs (total: 200)
# Processed page 3 - found 87 jobs (total: 287)
#
# Finished! Collected 287 unique titles from 287 jobs across 3 pages
# ✅ 3 contracts ready for processing
# ❌ Failed to post job Ireland – IT services: consulting, software development, Internet and support – Provision of an ICT Data Protection Compliance Software Solution for the administration of the Data Protection, Freedom of Information and Protected Disclosures Functions (HSE ref. 25027): 400 - {"errors":{"title":["The title may not be greater than 255 characters."]}}
# ❌ Failed to post job Italy – Research and experimental development services – Pre-commercial procurement of a research and development project of digital solutions and services for the socio-economic development of peripheral territorial communities through the creation and enhancement of cultural tourism destinations (CUP: C53D24000190007- CIG: B6937EED1F): 400 - {"errors":{"title":["The title may not be greater than 255 characters."]}}
# ❌ Failed to post job Ireland – Services furnished by business, professional and specialist organisations – ComReg T20327. Request for Tenders(RFT) to establish a Multi Supplier Framework Agreement for the provision of Services to support a review of competition in the market to the ComReg: 400 - {"errors":{"title":["The title may not be greater than 255 characters."]}}
# ✅ EU contracts uploaded to OppsLink

# %%
import httpx
import json
import time
from datetime import datetime, timezone
import html
import re
import requests

# Constants
API_KEY_OPPSLINK = "37c597e7bb52d26099ede8b8aa43b270"
HEADERS = {"Content-Type": "application/json"}
EU_API_KEY = "844692394d814535a9ed3a37f0ab01e1"
EU_API_URL = "https://tedweb.api.ted.europa.eu/private-search/api/v1/notices/search"

# Step 1: Get all employers and job titles from OppsLink
employers_dict, employers_list = get_all_employers(API_KEY_OPPSLINK)
all_titles = get_all_job_titles(API_KEY_OPPSLINK)

def clean_description(description):
    """Clean and format the description text."""
    if not description:
        return "Not Disclosed"
    cleaned = html.unescape(description)
    cleaned = cleaned.replace('\r\n', ' ').replace('\n', ' ')
    return ' '.join(cleaned.split()).strip()

def fetch_data(payload, page):
    for attempt in range(5):
        response = httpx.post(EU_API_URL, headers={
            "Content-Type": "application/json",
            "Authorization": f"Bearer {EU_API_KEY}",
        }, json=payload)

        if response.status_code == 200:
            return response.json().get("notices", [])
        elif response.status_code == 429:
            time.sleep(2 ** attempt)
        else:
            break
    return []

# Step 2: Scrape and filter EU contracts
all_eu_contracts = []
for page in range(1, 11):
    payload = {
        "query": "(classification-cpv IN (66171000 73100000 73200000 73300000 75211200 79411000 90713000)) AND (notice-type IN (qu-sy pin-cfc-standard subco cn-desg cn-social cn-standard pin-cfc-social))  SORT BY publication-number DESC",
        "page": page,
        "limit": 50,
        "fields": [
            "classification-cpv", "BT-24-Procedure", "BT-27-Procedure", "BT-27-Part", "BT-27-Lot",
            "publication-number", "BT-5141-Procedure", "BT-5141-Part", "BT-5141-Lot",
            "BT-5071-Procedure", "BT-5071-Part", "BT-5071-Lot", "BT-727-Procedure",
            "BT-727-Part", "BT-727-Lot", "place-of-performance", "procedure-type",
            "contract-nature", "buyer-name", "buyer-country", "publication-date",
            "deadline-receipt-request", "notice-title", "official-language", "notice-type",
            "links"
        ],
        "validation": False,
        "scope": "ACTIVE",
        "language": "EN"
    }

    new_contracts = fetch_data(payload, page)

    for contract in new_contracts:
        full_title = contract.get("notice-title", {}).get("eng", "")
        if not full_title:
            continue

        # Split title to retain first and last parts (e.g., "Country – Services – Description" → "Country – Description")
        if " – " in full_title:
            parts = full_title.split(" – ")
            if len(parts) >= 2:
                title = f"{parts[0]} – {parts[-1]}"
            else:
                title = full_title
        else:
            title = full_title

        if title in all_titles:
            print(f"⏩ Skipping duplicate title: {title}")
            continue

        official_languages = ', '.join([lang['label'] for lang in contract.get("official-language", [])])
        if 'English' not in official_languages:
            continue

        deadline = contract.get("deadline-receipt-request", [])
        deadline_date = deadline[0] if deadline else "2050-01-01T00:00:00Z"

        country = ', '.join({place['label'] for place in contract.get("place-of-performance", [])})
        client_name = contract.get("buyer-name", {}).get("eng", [""])[0] or "Not Disclosed"
        description = clean_description(contract.get("BT-24-Procedure", {}).get("eng", ""))
        cpv_codes = ', '.join([c["value"] for c in contract.get("classification-cpv", [])])
        value = contract.get("BT-27-Procedure", "") or "Unavailable"
        link = contract.get("links", {}).get("html", {}).get("ENG", "")

        all_eu_contracts.append({
            "title": title,
            "deadline": deadline_date,
            "country": country,
            "client": client_name,
            "description": description[:2000],
            "cpv_codes": cpv_codes,
            "value": value,
            "link": link
        })

    time.sleep(5)

print(f"✅ {len(all_eu_contracts)} contracts ready for processing")

# Step 3: Upload to OppsLink
for contract in all_eu_contracts:
    title = contract['title']
    if title in all_titles:
        print(f"⏩ Skipping duplicate title: {title}")
        continue

    client_name = contract['client']
    client_key = client_name.lower()

    employer_id = employers_dict.get(client_key)
    if employer_id is None:
        print(f"🔍 Employer '{client_name}' not found. Attempting to create...")
        employer_id = create_employer(client_name)
        if employer_id:
            employers_dict[client_key] = employer_id
        else:
            print(f"🚫 Skipping contract '{title}' — failed to create employer.")
            continue

    try:
        formatted_deadline = datetime.fromisoformat(contract["deadline"]).strftime("%Y-%m-%d")
    except:
        formatted_deadline = "2025-12-31"

    job_data = {
        "api_key": API_KEY_OPPSLINK,
        "active": 1,
        "featured": 0,
        "title": title,
        "employer_id": employer_id,
        "description": contract['description'],
        "how_to_apply": "contact@example.com",
        "activation_date": datetime.now(timezone.utc).strftime("%Y-%m-%d %H:%M:%S"),
        "expiration_date": formatted_deadline,
        "location": contract['country'] or "EU",
        "custom_fields": [
            {"name": "Contract Value", "value": contract['value']},
            {"name": "Contract Link", "value": contract['link']},
            {"name": "CPV Codes", "value": contract['cpv_codes']},
            {"name": "Application deadline", "value": formatted_deadline, "type": "date"}
        ]
    }

    success = create_job(job_data)
    if success:
        all_titles.add(title)

print("✅ EU contracts uploaded to OppsLink")
# Out:
# Starting to collect all employers...
# Processed page 1 - found 100 employers (total: 100)
# Processed page 2 - found 100 employers (total: 200)
# Processed page 3 - found 100 employers (total: 300)
# Processed page 4 - found 100 employers (total: 400)
# Processed page 5 - found 92 employers (total: 492)
#
# Finished! Collected 485 unique employers across 5 pages
# Starting to collect all job titles...
# Processed page 1 - found 100 jobs (total: 100)
# Processed page 2 - found 100 jobs (total: 200)
# Processed page 3 - found 87 jobs (total: 287)
#
# Finished! Collected 287 unique titles from 287 jobs across 3 pages
# ⏩ Skipping duplicate title: Ireland – Provision of micro-credential courses in various fields of Renewable Energy /Greentech
# ⏩ Skipping duplicate title: Norway – 2025/782 - Parallel framework agreements for consultancy services within ICT security.
# ⏩ Skipping duplicate title: Norway – Monitoring health of test animals.
# ⏩ Skipping duplicate title: Switzerland – CRO Services Pool
# ⏩ Skipping duplicate title: Italy – Statistical methods in ecotoxicology (hypothesis testing)
# ⏩ Skipping duplicate title: Norway – Framework agreement operation of hoppid.no office for Molde municipality 2025 - 2029
# ⏩ Skipping duplicate title: Ireland – FCC/283/24.F- Provision of Services for the Co-Ordination and Delivery of the Student Enterprise Programme for Fingal Local Enterprise Office for Fingal County Coucil.
# ⏩ Skipping duplicate title: Norway – Procurement - Project assistance - Concept evaluation Transition to cloud based financial services
# ⏩ Skipping duplicate title: Norway – Procurement of consultancy services in the energy field: Coordinate the project microenergy system Furuset and assistance in the area of energy flexibility.
# ⏩ Skipping duplicate title: Norway – Financial services
# ⏩ Skipping duplicate title: Ireland – RFT for the provision of two business cases, including detailed procurement strategy plans and market engagement reports for two green hydrogen refuelling stations in Belfast and Dublin.
# ⏩ Skipping duplicate title: Norway – Audit of the National Offices for Erasmus+
# ⏩ Skipping duplicate title: Germany – 81316188 - Localised Implementation and Multi-stakeholder management with the VPPIC project
# ⏩ Skipping duplicate title: Norway – Framework agreement operation of hoppid.no office for Molde municipality 2025 - 2029
# ⏩ Skipping duplicate title: Ireland – Request for Tenders for the Provision of services to design and develop a programme to enhance Innovation Capacity in Defence
# ⏩ Skipping duplicate title: Italy – Building green and climate neutral city hubs across European cities (II^ Edition - Follower cities)
# ⏩ Skipping duplicate title: Norway – 2025/782 - Parallel framework agreements for consultancy services within ICT security.
# ⏩ Skipping duplicate title: Luxembourg – "Rethinking Territories within Planetary Boundaries [TERRBOUND]"
# ⏩ Skipping duplicate title: Norway – 2025/895 - Consultancy assignment for the management and further development of Cognos/BI systems in Statsbygg.
# ⏩ Skipping duplicate title: Norway – Obtaining relevance knowledge base for the Ministry of Defence's FUI policy and FUI system.
# ⏩ Skipping duplicate title: Ireland – DB202503 Dublin Coast Destination and Experience Development Plan
# ⏩ Skipping duplicate title: Norway – Evaluation of the implementation of a plan for stepping-up against violence and child abuse and domestic violence (2024-2028)
# ⏩ Skipping duplicate title: Montenegro – Capacity Building for IPA Programming and Implementation
# ⏩ Skipping duplicate title: Ireland – The Provision of Media Relations, Corporate Communications and Public Affairs Services to the LDA - Pro244
# ⏩ Skipping duplicate title: Germany – PRO-2390010686 - Maintenance and Development of the ECB's Environmental Management System
# ⏩ Skipping duplicate title: Norway – Analysis of pros and cons of the health platform
# ⏩ Skipping duplicate title: Türkiye – Developing National Stocktake System for Global Efforts on Climate Change
# ⏩ Skipping duplicate title: Belgium – Design and implementation of "Industrial Decarbonisation Bank"
# ⏩ Skipping duplicate title: Norway – Socio-economic analysis of satellite based services for position determination, navigation and time determination (PNT).
# ⏩ Skipping duplicate title: Norway – Commercialisation services
# ⏩ Skipping duplicate title: Türkiye – Developing National Stocktake System for Global Efforts on Climate Change
# ⏩ Skipping duplicate title: Ireland – Provision of Industrial Contractor Services for Pilot Test of New Technology
# ⏩ Skipping duplicate title: Ireland – Provision of an ICT Data Protection Compliance Software Solution for the administration of the Data Protection, Freedom of Information and Protected Disclosures Functions (HSE ref. 25027)
# ⏩ Skipping duplicate title: China – Technical assistance to "Understanding Chinese Legal Reform (EUCLERA) 2025-2030"
# ⏩ Skipping duplicate title: Ireland – Feasibility Study on the Establishment of a MAP (Mountain Access Project) for the Brandon Mountain Range
# ⏩ Skipping duplicate title: Ireland – Project Management Led Multi-Disciplinary Project Delivery Team for the Cork Event Centre
# ⏩ Skipping duplicate title: Germany – 81316177-Fortalecimiento de capacidades y articulación interinstitucional con enfoques transformadores de género en Péru
# ⏩ Skipping duplicate title: Germany – 81316582-Technical assistance to enhance trade effluent management practices in Lusaka
# ⏩ Skipping duplicate title: Finland – Regional Teachers Initiative for Africa (RTIA): Technical Expertise for Zambia
# ⏩ Skipping duplicate title: Ireland – The Provision of Media Relations, Corporate Communications and Public Affairs Services to the LDA - Pro244
# ⏩ Skipping duplicate title: Portugal – EU-QUALITY - Development of a quality management system for drug demand reduction in Europe
# ⏩ Skipping duplicate title: Norway – Independent inspections with project implementation, technical assistance and capacity building.
# ⏩ Skipping duplicate title: Ireland – Building Ireland’s Insurance Innovation Sandbox
# ⏩ Skipping duplicate title: Belgium – Assessment study for data and metadata availability and adequacy for MSFD Article 19(3) obligations
# ⏩ Skipping duplicate title: Kosovo – EU Integration Support Facility
# ⏩ Skipping duplicate title: Germany – Upskilling of Albanian ITC Company Employees
# ⏩ Skipping duplicate title: Cyprus – CALL FOR TENDERS FOR "INVESTIGATION ON PLANKTONIC BIO COMMUNITIES IN MARINE WATERS OF THE REPUBLIC OF CYPRUS (PLANKTON MSFD-CY)" (TENDER NO.: 06/2025).
# ⏩ Skipping duplicate title: Ireland – Provision of a Sustainable Development Strategy
# ⏩ Skipping duplicate title: Ireland – The Provision of Engineering Consultancy Support to CRU Lot 1: Gas Engineering Consultancy Services Lot 2: Electricity Engineering Consultancy Services
# ⏩ Skipping duplicate title: Norway – Dynamic purchasing system - assistance with IT and service development.
# ⏩ Skipping duplicate title: Belgium – EU Road Safety Exchange +
# ⏩ Skipping duplicate title: Ireland – MI-CFT25-007 Call for Tender for the provision of Vertebrate Necropsy, Sample Recovery, and Contaminant Analysis Services
# ⏩ Skipping duplicate title: Malta – SPD8/2025/048 - FRAMEWORK CONTRACT FOR AIR MONITORING SERVICES ACROSS VARIOUS WASTESERV SITES IN MALTA AND GOZO
# ⏩ Skipping duplicate title: Ireland – Request for Research Intelligence Database(s) and related Research Analytics Service.
# ⏩ Skipping duplicate title: Belgium – Multiple framework contracts in cascade for legal support services for the compliance assessment of national transposing measures in the health and food safety areas, in the context of the enlargement
# ⏩ Skipping duplicate title: Norway – Evaluation of the Election Directorate's services and the election implementation survey 2025.
# ⏩ Skipping duplicate title: Norway – Assistance with the contract review for the assignment "Traffic Contract Review".
# ⏩ Skipping duplicate title: Ireland – Provision of the Annual National Household Travel Survey
# ⏩ Skipping duplicate title: Denmark – Monitoring, Evaluation, Accountability and Learning (MEAL) under the Migration Programmes
# ⏩ Skipping duplicate title: Ireland – Assessment of the Land Use, Land-use Change and Forestry in Ireland for Coillte CGA
# ⏩ Skipping duplicate title: Norway – Information Security
# ⏩ Skipping duplicate title: Ireland – Request for Tenders for the provision of an Enterprise Data Transformation Initiative
# ⏩ Skipping duplicate title: Norway – Radiocarbon dating service
# ⏩ Skipping duplicate title: Norway – Mapping nature types in fresh water in accordance with the Norwegian Environment Agency ́s mapping instructions 2025
# ⏩ Skipping duplicate title: Ireland – Media Monitoring Service
# ⏩ Skipping duplicate title: Norway – Parallel framework agreements for research and development.
# ⏩ Skipping duplicate title: Belgium – Trade Sustainability Impact Assessment in support of Free Trade Agreement (FTA) negotiations between the EU and Thailand
# ⏩ Skipping duplicate title: Norway – 25/1602 - Financial and legal advice for the sale of municipal nurseries.
# ⏩ Skipping duplicate title: Ireland – Legionella Risk Assessments
# ⏩ Skipping duplicate title: Norway – Microalgea Biomass
# ⏩ Skipping duplicate title: Norway – Evaluation of four trials with exemption from the current provisions in the Education Act
# ⏩ Skipping duplicate title: Germany – Preclinical toxicity study in minipigs - PR946117-3310-I
# ⏩ Skipping duplicate title: Italy – Guidelines development training
# ⏩ Skipping duplicate title: Ireland – Exhibition Design and Project Management Services for the National Archives’ 1926 Census Exhibition in Dublin, London (UK) and Boston (US).
# ⏩ Skipping duplicate title: Norway – Analysis of pros and cons of the health platform
# ⏩ Skipping duplicate title: Finland – Research on the Impact of the Digital Transformation Priority on Organisations in Erasmus+ and European Solidarity Corps projects.
# ⏩ Skipping duplicate title: Ireland – Request for Tenders for the provision of food preparation and/or analytical services for the 2025-2026 FSAI Total Diet Study
# ⏩ Skipping duplicate title: Norway – Contribution to the indicator report: Framework agreement for analyses and development of indicators for the national research and innovation system.
# ⏩ Skipping duplicate title: Norway – Evaluation of follow-up measures
# ⏩ Skipping duplicate title: Norway – Mapping the clarification measure.
# ⏩ Skipping duplicate title: Belgium – Evolution of Galileo SAR-RLS beacons for maritime environment
# ⏩ Skipping duplicate title: Norway – Boards
# ⏩ Skipping duplicate title: Norway – 24/02131 Framework Agreement for the Provision of Methylation and Mitochondrial Sequencing Analysis Services - NIPH
# ⏩ Skipping duplicate title: Germany – 81315500-Consulting services for strengthening capacities of EAC Secretariat and its partners to manage nature-based solutions in East Africa
# ⏩ Skipping duplicate title: Norway – 25-00829 Consultancy services - International Nuclear Security - DSA
# ⏩ Skipping duplicate title: Ireland – CIE Board Advisory Services Qualification System
# ⏩ Skipping duplicate title: Sweden – Financial advisory services for financing and risk-sharing of new nuclear reactors
# ⏩ Skipping duplicate title: Germany – 81314067 - DBS SME Training + Coaching Services
# ⏩ Skipping duplicate title: Germany – 81314067 - DBS SME Training + Coaching Services - Category 3 (3/3)
# ⏩ Skipping duplicate title: Germany – 81314067 - DBS SME Training + Coaching Services - Category 2 (2/3)
# ⏩ Skipping duplicate title: Denmark – Tender for Assistance with administration of DANIDA bilateral advisers
# ⏩ Skipping duplicate title: Ireland – Research for the Health Behaviour in School-Aged Children (2026) Collaborative Study
# ⏩ Skipping duplicate title: Germany – 81314067 - DBS SME Training + Coaching Services - Category 1
# ⏩ Skipping duplicate title: Denmark – Tender for Assistance with administration of DANIDA bilateral advisers
# ⏩ Skipping duplicate title: Norway – 24/02131 Framework Agreement for the Provision of Methylation and Mitochondrial Sequencing Analysis Services - NIPH
# ⏩ Skipping duplicate title: Belgium – Multiple Sourcing Framework Contracts to Speed up the Development of and Access to Innovative Medical Countermeasures: Next-Generation Influenza Vaccines
# ⏩ Skipping duplicate title: Norway – Evaluation of the Municipal Act of 2018
# ⏩ Skipping duplicate title: Norway – Evaluation of the knowledge sector ́s computer partnership (KUDAF)
# ⏩ Skipping duplicate title: Belgium – Enhancing coordination and synergies in the field of ocean observation in the EU
# ⏩ Skipping duplicate title: Ireland – Framework Agreement for Water Quality Services
# ⏩ Skipping duplicate title: Ireland – TII463 MetroLink Delivery Oversight Group - Chairperson Qualification System
# ⏩ Skipping duplicate title: Ireland – Establishment of a Panel of Consultants for Local Enterprise Office Westmeath to deliver LEAN for Business and Green for Business Programmes
# ⏩ Skipping duplicate title: Ireland – Call for Expression of Interest for the Establishment of a database of external remunerated experts providing expertise in the field of industrial relations and social dialogue to Eurofound
# ⏩ Skipping duplicate title: Ireland – Dive Related Services for the National Monuments Service, Department of Housing, Local Government and Heritage
# ⏩ Skipping duplicate title: Norway – 24/02131 Framework Agreement for the Provision of Methylation and Mitochondrial Sequencing Analysis Services - NIPH
# ⏩ Skipping duplicate title: Belgium – Comparative study on best practices for a stronger EU sanction enforcement
# ⏩ Skipping duplicate title: Norway – 25-00829 Consultancy services - International Nuclear Security - DSA
# ⏩ Skipping duplicate title: Norway – Mapping plans for area efficiency at universities and university colleges.
# ⏩ Skipping duplicate title: Ireland – Ballinasloe ORIS Outdoor Recreation Park Feasibility Study and Prelim Design
# ⏩ Skipping duplicate title: Germany – 81314465-Inclusion of People with Disabilities (PwD) with the private sector in Jordan
# ⏩ Skipping duplicate title: Norway – Mapping how the information and liability and joint and several liability in the general application scheme function.
# ⏩ Skipping duplicate title: Ireland – Understanding and Forecasting Digital Skills Needs in Ireland to 2030
# ⏩ Skipping duplicate title: Ireland – Establishment of Consultant Panel for Enhancing Processes, Systems, Teams, and Structures under title III services for Technological University Dublin at Technological University Dublin
# ⏩ Skipping duplicate title: Belgium – Framework contract for the provision of services to support the implementation of the Single European Sky policy
# ⏩ Skipping duplicate title: Norway – Dynamic procurement scheme for biology and popular science assistance.
# ⏩ Skipping duplicate title: Ireland – Consultancy Services Ballycasey Campus
# ⏩ Skipping duplicate title: Netherlands – CKIC-FIN-001
# ⏩ Skipping duplicate title: Ireland – CIE Board Advisory Services Qualification System
# ⏩ Skipping duplicate title: Norway – Attitude survey on ethnic and religious minorities 2025-2027
# ⏩ Skipping duplicate title: Ireland – Interreg NWE Financial Management Consultancy Tender
# ⏩ Skipping duplicate title: Ireland, Greece – Interreg NWE Financial Management Consultancy
# ⏩ Skipping duplicate title: Norway – Dynamic purchasing system CLIMATE, ENVIRONMENT AND NATURE
# ⏩ Skipping duplicate title: Norway – Framework agreement for "Art in numbers"
# ⏩ Skipping duplicate title: Germany – 81314138-Comprehensive Gender Responsive Business Approaches Services for SMEs in Jordan
# ⏩ Skipping duplicate title: Sweden – Central Evaluation Ukraine
# ⏩ Skipping duplicate title: Denmark – Evaluation of the Danish Energy Partnership Programmes
# ⏩ Skipping duplicate title: Ireland – HRB 2025 Open Research Publishing
# ⏩ Skipping duplicate title: Ireland – ComReg T20327. Request for Tenders(RFT) to establish a Multi Supplier Framework Agreement for the provision of Services to support a review of competition in the market to the ComReg
# ⏩ Skipping duplicate title: Malta – CT7001/2024 - Dynamic Purchasing System for the Provision of Specialised Resources for The Malta Digital Innovation Authority (MDIA) (Eu Funded)
# ⏩ Skipping duplicate title: Norway – Framework agreement for consultancy services for Education and Research in development contexts
# ⏩ Skipping duplicate title: Ireland – Services for Biodiversity Policy Analysis and Stakeholder Engagement
# ⏩ Skipping duplicate title: Netherlands – Soil and ecological Expert support for search area 6/7 in the Dutch Offshore Wind Farm Zone
# ⏩ Skipping duplicate title: Norway – Framework agreement for management support for the fishing area.
# ⏩ Skipping duplicate title: Germany – Preclinical toxicity study in minipigs - PR806698-3310-I
# ⏩ Skipping duplicate title: Norway – Quality assurance of pH baskets and follow-up of the municipality ́s internal control for the operation of liming installations.
# ⏩ Skipping duplicate title: Germany – 81314067 - DBS SME Training + Coaching Services
# ⏩ Skipping duplicate title: Germany – 81313481-Strengthening of analytical capacities and policy formulation for a green transformation in Indonesia
# ⏩ Skipping duplicate title: Germany – 81314415 - Promotion of the political, administrative environment and technical implementation of water and wastewater management
# ⏩ Skipping duplicate title: Norway – Dynamic purchasing system - Consultancy consultancy services in the technical sector for 6 municipalities in Telemark.
# ⏩ Skipping duplicate title: Ireland – Professional Services for an independent interim and final external evaluation of Developing Irish Sea Cooperation (DISC)
# ⏩ Skipping duplicate title: Norway – Disposal of pipelines, cables and other infrastructure on the Norwegian continental shelf.
# ⏩ Skipping duplicate title: Norway – Communication services, framework agreement
# ⏩ Skipping duplicate title: Sweden – National Team Leader, EU Accession Support and Administrative support for project in Ukraine
# ⏩ Skipping duplicate title: Norway – 25/00180 Procurement of a follow-up and result evaluation of Bo safe home reform - The Norwegian Directorate of Health
# ⏩ Skipping duplicate title: Switzerland – Project UR_01132-01 for the implementation of the ‘Circular Electronics initiative (CEI)’ Programme (mid-2025 to mid-2029)
# ⏩ Skipping duplicate title: Norway – Evaluation and socio-economic analysis of Norwegian participation in Erasmus+, the Eu's programme for education, training, youth and sports.
# ⏩ Skipping duplicate title: Ireland – Request for Tenders for the Provision of Consultancy Services for Rail Operations Review
# ⏩ Skipping duplicate title: Germany – 81314156-Building MSMEs' skills and strengthening financial service providers' capacity through training and MSME-focused financial products
# ⏩ Skipping duplicate title: Norway – Evaluation and socio-economic analysis of Norwegian participation in the EU's framework programmes for research and innovation.
# ⏩ Skipping duplicate title: Norway – Courses - Horizon Europe and FP10
# ⏩ Skipping duplicate title: Ireland – IE Board and Senior Management Advisory Services
# ⏩ Skipping duplicate title: Norway – Evaluation of green platform
# ✅ 1 contracts ready for processing
# ❌ Failed to post job Italy – Pre-commercial procurement of a research and development project of digital solutions and services for the socio-economic development of peripheral territorial communities through the creation and enhancement of cultural tourism destinations (CUP: C53D24000190007- CIG: B6937EED1F): 400 - {"errors":{"title":["The title may not be greater than 255 characters."]}}
# ✅ EU contracts uploaded to OppsLink
